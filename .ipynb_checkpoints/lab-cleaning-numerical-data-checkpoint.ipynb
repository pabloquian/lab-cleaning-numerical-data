# %% [markdown]
# # Lab | Cleaning numerical data

# %% [markdown]
# For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in files_for_lab folder.
#
# Context
# An auto insurance company has collected some data about its customers including their demographics, education, employment, policy details, vehicle information on which insurance policy is, and claim amounts. You will help the senior management with some business questions that will help them to better understand their customers, improve their services, and improve profitability.
#
# Some business Objectives:
# - Retain customers,
# - Analyze relevant customer data,
# - Develop focused customer retention programs.
# - Based on the analysis, take targeted actions to increase profitable customer response, retention, and growth.
#
#
#
# Steps:
#
# 1. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer
#
# 2. First look at its main features (head, shape, info). NOTE The target column is total_claim_amount
#
# 3. Rename the columns so they follow the PE8 (snake case) (lower_case_with_underscores)
#
# 4. Change effective to date column to datetime format.
#
# 5. Create a NEW dataframe using only the numerical data called numerical. Use this for the following questions.
#
# 6. Define a function that differentiates between continuous and discrete variables. Hint: The number of unique values might be useful. Store continuous data into a continuous_df variable and do the same for discrete_df
#
# 7. Plot a correlation matrix, comment what you see.
#
# 8. Create a function to plot every discrete variable. Do the same with the continuous variables (Be Careful, you may need to change the plot type to one better suited for continuous data!)
#
# 9. Comment what you can see in the plots.
#
# 10. Look for outliers in the continuous variables. (HINT: There’s a good plot to do that!)
#
# 11. Did you find outliers? Comment what you will do with them. If you decide to remove them, do that now. Also, remove them from your main dataframe.
#
# 12. Check all columns for NaN values. Decide what (if anything) you will need to do with them, do that now.
#
# 13. Save the numerical_df to csv as numerical.csv You will use this file again this week.

# %%
# import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# load dataset
customer = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
customer.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %%
# I define a fuction to rename the columns so they following the PE8 
def lowerand_(df):
    df.columns = df.columns.str.lower()
    df.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)
    return df

# %%
lowerand_(customer)
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
# I will change 'effective_to_date' column to datetime datatype
customer['effective_to_date'] = pd.to_datetime(customer['effective_to_date'])
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_22804\3451636616.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   customer['effective_to_date'] = pd.to_datetime(customer['effective_to_date'])

# %%
customer.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# sales_channel                            object
# total_claim_amount                      float64
# vehicle_class                            object
# vehicle_size                             object
# dtype: object

# %%
# create a new dataframe with only the numerical variables
numerical = customer.select_dtypes('number')

# %%
numerical.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# 2                          0                   2          566.472247
# 3                          0                   7          529.881344
# 4                          0                   1          138.130879

# %%
for col in numerical.columns:
    print(numerical[col].nunique())
# Out:
# 8041
# 5694
# 202
# 36
# 100
# 6
# 9
# 5106

# %%
# I want to know if the numerical variables are discrete or continuous so I will consider that
# if more than the 50% of the values are unique, that is a continuous variable.

# %%
for col in numerical.columns:
    print(round(numerical[col].nunique()/len(numerical),2))
# Out:
# 0.88
# 0.62
# 0.02
# 0.0
# 0.01
# 0.0
# 0.0
# 0.56

# %%
# defining a fuction to create two dataframes. One with discrete numerical variables and the other one with continuous variables.
discrete = pd.DataFrame()
continuous = pd.DataFrame()

def discrete_continuous(df):
    
    global discrete, continuous

    for col in df.columns:
    
        if (df[col].dtype == 'float64') | (round(df[col].nunique()/len(df),2) > 0.5):
            continuous[col] = df[col]
        else:
            discrete[col] = df[col]

# %%
# I apply the function
discrete_continuous(numerical)

# %%
# Check if it worked
display(continuous.head())
discrete.head()
# Out:
#    customer_lifetime_value  income  total_claim_amount
# 0              2763.519279   56274          384.811147
# 1              6979.535903       0         1131.464935
# 2             12887.431650   48767          566.472247
# 3              7645.861827       0          529.881344
# 4              2813.692575   43836          138.130879
#    monthly_premium_auto  months_since_last_claim  \
# 0                    69                       32
# 1                    94                       13
# 2                   108                       18
# 3                   106                       18
# 4                    73                       12
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    number_of_policies
# 0                   1
# 1                   8
# 2                   2
# 3                   7
# 4                   1

# %%
discrete_corr = discrete.corr()
continuous_corr = continuous.corr()

sns.heatmap(discrete_corr, annot=True)
plt.show()

sns.heatmap(continuous_corr, annot=True)
plt.show()

# %%
# There is very little correlation between the variables in both dataframes.
# The max correlation is between 'income' and 'total_claim_amount' that have negative correlation.
# This make sense as more income you have less you case about claiming money.

# %%
# Create a function to plot every discrete variable. Do the same with the continuous variables
# (Be Careful, you may need to change the plot type to one better suited for continuous data!).

# %%
def plot_hist(df):
    
    for col in df.columns:
        sns.displot(df[col])
    plt.show()

# %%
def plot_bar(df):
    
    for col in df.columns:
        sns.barplot(x=df[col].value_counts().index, y=df[col].value_counts())
        plt.show()

# %%
# check the functions
plot_hist(continuous)
# Out:
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
discrete_selection = discrete.drop(['number_of_open_complaints','number_of_policies'], axis=1)
# I make a selection on the district variables as I consider 'number_of_open_complaints' and 'number_of_policies' categorical variables-

# %%
plot_hist(discrete_selection)
# Out:
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# First I wanted to plot discrete and continuous variables different but discrete variables have
# a lot of possible values on the x axis so it was better to plot them with an histogram plot as well

# %%
# Some of the plots of continuous variables are skewed beacause of outliers.

# %%
# I will check the outliers making box plots
# I define a function for that
def plot_box(df):
    
    for col in df.columns:
        sns.boxplot(x=df[col])
        plt.show()

# %%
plot_box(continuous)

# %%
# The outliers are reasonable values. I will leave them for the model.

# %%
# check for nan values
customer.isnull().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %%
# Save the numerical dataframe as csv
numerical.to_csv('numerical.csv')

# %%
# LAB FINISHED

# %%
# START NEXT LAB

# %% [markdown]
# # Lab | Cleaning categorical data

# %% [markdown]
# 1. Find all of the categorical data. Save it in a categoricalvariable.
#
# 2. Check for NaN values and decide what to do with them, do it now.
#
# 3. Check all unique values of columns.
#
# 4. Check dtypes. Do they all make sense as categorical data?
#
# 5. Does any column contain alpha and numeric data? Decide how to clean it and do it now.
#
# 6. Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions and do it now.
#
# 7. Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?
#
# 8. Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.
#
# 9. Save the cleaned catagorical dataframe as categorical.csv You will use this file again this week.

# %%
# save categorical data in a new variable
categorical = customer.select_dtypes(exclude='number')

# %%
# As I discovered before that 'number_of_open_complaints' and 'number_of_policies' are in fact
# categorical, I will add them.

# %%
categorical['number_of_open_complaints'] = customer['number_of_open_complaints']
categorical['number_of_policies'] = customer['number_of_policies']

# %%
# I will change their data type to object
categorical['number_of_policies'] = categorical['number_of_policies'].astype(object)
categorical['number_of_open_complaints'] = categorical['number_of_open_complaints'].astype(object)

# %%
categorical.dtypes
# Out:
# customer                             object
# state                                object
# response                             object
# coverage                             object
# education                            object
# effective_to_date            datetime64[ns]
# employmentstatus                     object
# gender                               object
# location_code                        object
# marital_status                       object
# policy_type                          object
# policy                               object
# renew_offer_type                     object
# sales_channel                        object
# vehicle_class                        object
# vehicle_size                         object
# number_of_open_complaints            object
# number_of_policies                   object
# dtype: object

# %%
# check for nan values
categorical.isnull().sum()
# Out:
# customer                     0
# state                        0
# response                     0
# coverage                     0
# education                    0
# effective_to_date            0
# employmentstatus             0
# gender                       0
# location_code                0
# marital_status               0
# policy_type                  0
# policy                       0
# renew_offer_type             0
# sales_channel                0
# vehicle_class                0
# vehicle_size                 0
# number_of_open_complaints    0
# number_of_policies           0
# dtype: int64

# %%
# check unique values of columns
for col in categorical.columns:
    display(categorical[col].value_counts())
# Out:
# customer
# BU79786    1
# PU81096    1
# CO75086    1
# WW52683    1
# XO38850    1
#           ..
# HS14476    1
# YL91587    1
# CT18212    1
# EW35231    1
# Y167826    1
# Name: count, Length: 9134, dtype: int64
# state
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: count, dtype: int64
# response
# No     7826
# Yes    1308
# Name: count, dtype: int64
# coverage
# Basic       5568
# Extended    2742
# Premium      824
# Name: count, dtype: int64
# education
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: count, dtype: int64
# effective_to_date
# 2011-01-10    195
# 2011-01-27    194
# 2011-02-14    186
# 2011-01-26    181
# 2011-01-17    180
# 2011-01-19    179
# 2011-01-31    178
# 2011-01-03    178
# 2011-01-20    173
# 2011-02-26    169
# 2011-01-28    169
# 2011-02-19    168
# 2011-01-05    167
# 2011-02-27    167
# 2011-01-11    166
# 2011-02-04    164
# 2011-02-10    161
# 2011-02-28    161
# 2011-01-02    160
# 2011-01-21    160
# 2011-01-29    160
# 2011-02-22    158
# 2011-02-05    158
# 2011-02-03    158
# 2011-02-07    157
# 2011-02-12    156
# 2011-01-23    155
# 2011-02-01    154
# 2011-01-18    154
# 2011-01-15    153
# 2011-01-14    152
# 2011-02-11    151
# 2011-01-07    151
# 2011-01-25    151
# 2011-02-25    149
# 2011-01-08    149
# 2011-02-18    149
# 2011-02-02    149
# 2011-01-01    148
# 2011-02-21    148
# 2011-01-24    147
# 2011-01-09    146
# 2011-01-30    145
# 2011-01-13    145
# 2011-02-06    144
# 2011-01-06    143
# 2011-02-23    143
# 2011-01-16    142
# 2011-02-16    139
# 2011-02-13    139
# 2011-02-24    139
# 2011-02-09    137
# 2011-02-17    136
# 2011-01-22    136
# 2011-02-08    134
# 2011-02-20    132
# 2011-02-15    130
# 2011-01-12    126
# 2011-01-04    115
# Name: count, dtype: int64
# employmentstatus
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: count, dtype: int64
# gender
# F    4658
# M    4476
# Name: count, dtype: int64
# location_code
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: count, dtype: int64
# marital_status
# Married     5298
# Single      2467
# Divorced    1369
# Name: count, dtype: int64
# policy_type
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: count, dtype: int64
# policy
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: count, dtype: int64
# renew_offer_type
# Offer1    3752
# Offer2    2926
# Offer3    1432
# Offer4    1024
# Name: count, dtype: int64
# sales_channel
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: count, dtype: int64
# vehicle_class
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: count, dtype: int64
# vehicle_size
# Medsize    6424
# Small      1764
# Large       946
# Name: count, dtype: int64
# number_of_open_complaints
# 0    7252
# 1    1011
# 2     374
# 3     292
# 4     149
# 5      56
# Name: count, dtype: int64
# number_of_policies
# 1    3251
# 2    2294
# 3    1168
# 7     433
# 9     416
# 4     409
# 5     407
# 8     384
# 6     372
# Name: count, dtype: int64

# %%
# Some columns contain numeric characters but they are fine as object data type.
# I will clean the columns 'policy_type' and 'policy' as I can have the same information in less columns
# and this is something beneficial for the performance of our model.

# %%
# I will leave 'policy_type' as it is and I will leave just the numbers of 'policy'
# The logic behind this decision is that 'policy_type' will contain the policy type and policy will
# contain the level of that policy.
# I will define a function for this
def clean_policy(x):
        if "L1" in x:
            return "1"
        elif "L2" in x:
            return "2"
        elif "L3" in x:
            return "3"
        else:
            return "U"

# %%
categorical['policy'] = categorical['policy'].apply(clean_policy)
categorical['policy'].value_counts()
# Out:
# policy
# 3    4588
# 2    2881
# 1    1665
# Name: count, dtype: int64

# %%
categorical.rename(columns={'policy': 'policy_level'}, inplace=True)

# %%
# When I onehot encode these columns I will get just 4 columns, as I will drop the first one on both

# %%
# I won't change anything else. It is ready to encode and start building the model

# %%
#save the dataframe into a csv
categorical.to_csv('categorical.csv')

# %%
# FINISH OF THE LAB

# %% [markdown]
# # Lab | Feature extraction

# %% [markdown]
# For this lab, we will be using the same dataset we used in the previous labs. We recommend using the same notebook since you will be reusing the same variables you previous created and used in labs.
#
# Instructions:
# 1. Open the categorical dataframe we created before.
# 2. Plot all the categorical variables with the proper plot. What can you see?
# 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?
# 4. Make any changes you feel are necessary.
# 5. Plot time variable. Can you extract something from it?
# 6. The time variable can be useful. You shoud transform its data into a more useful form. Hint: Day, week, and month as integers might be useful.

# %%
categorical.head()
# Out:
#   customer       state response  coverage education effective_to_date  \
# 0  BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1  QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2  AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3  WW63253  California       No     Basic  Bachelor        2011-01-20
# 4  HB64268  Washington       No     Basic  Bachelor        2011-02-03
#
#   employmentstatus gender location_code marital_status     policy_type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#   policy_level renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 0            3           Offer1         Agent   Two-Door Car      Medsize
# 1            3           Offer3         Agent  Four-Door Car      Medsize
# 2            3           Offer1         Agent   Two-Door Car      Medsize
# 3            2           Offer1   Call Center            SUV      Medsize
# 4            1           Offer1         Agent  Four-Door Car      Medsize
#
#   number_of_open_complaints number_of_policies
# 0                         0                  1
# 1                         0                  8
# 2                         0                  2
# 3                         0                  7
# 4                         0                  1

# %%
# I check the unique values of each column
for col in categorical.columns:
    print(categorical[col].value_counts())
# Out:
# customer
# BU79786    1
# PU81096    1
# CO75086    1
# WW52683    1
# XO38850    1
#           ..
# HS14476    1
# YL91587    1
# CT18212    1
# EW35231    1
# Y167826    1
# Name: count, Length: 9134, dtype: int64
# state
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: count, dtype: int64
# response
# No     7826
# Yes    1308
# Name: count, dtype: int64
# coverage
# Basic       5568
# Extended    2742
# Premium      824
# Name: count, dtype: int64
# education
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: count, dtype: int64
# effective_to_date
# 2011-01-10    195
# 2011-01-27    194
# 2011-02-14    186
# 2011-01-26    181
# 2011-01-17    180
# 2011-01-19    179
# 2011-01-31    178
# 2011-01-03    178
# 2011-01-20    173
# 2011-02-26    169
# 2011-01-28    169
# 2011-02-19    168
# 2011-01-05    167
# 2011-02-27    167
# 2011-01-11    166
# 2011-02-04    164
# 2011-02-10    161
# 2011-02-28    161
# 2011-01-02    160
# 2011-01-21    160
# 2011-01-29    160
# 2011-02-22    158
# 2011-02-05    158
# 2011-02-03    158
# 2011-02-07    157
# 2011-02-12    156
# 2011-01-23    155
# 2011-02-01    154
# 2011-01-18    154
# 2011-01-15    153
# 2011-01-14    152
# 2011-02-11    151
# 2011-01-07    151
# 2011-01-25    151
# 2011-02-25    149
# 2011-01-08    149
# 2011-02-18    149
# 2011-02-02    149
# 2011-01-01    148
# 2011-02-21    148
# 2011-01-24    147
# 2011-01-09    146
# 2011-01-30    145
# 2011-01-13    145
# 2011-02-06    144
# 2011-01-06    143
# 2011-02-23    143
# 2011-01-16    142
# 2011-02-16    139
# 2011-02-13    139
# 2011-02-24    139
# 2011-02-09    137
# 2011-02-17    136
# 2011-01-22    136
# 2011-02-08    134
# 2011-02-20    132
# 2011-02-15    130
# 2011-01-12    126
# 2011-01-04    115
# Name: count, dtype: int64
# employmentstatus
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: count, dtype: int64
# gender
# F    4658
# M    4476
# Name: count, dtype: int64
# location_code
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: count, dtype: int64
# marital_status
# Married     5298
# Single      2467
# Divorced    1369
# Name: count, dtype: int64
# policy_type
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: count, dtype: int64
# policy_level
# 3    4588
# 2    2881
# 1    1665
# Name: count, dtype: int64
# renew_offer_type
# Offer1    3752
# Offer2    2926
# Offer3    1432
# Offer4    1024
# Name: count, dtype: int64
# sales_channel
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: count, dtype: int64
# vehicle_class
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: count, dtype: int64
# vehicle_size
# Medsize    6424
# Small      1764
# Large       946
# Name: count, dtype: int64
# number_of_open_complaints
# 0    7252
# 1    1011
# 2     374
# 3     292
# 4     149
# 5      56
# Name: count, dtype: int64
# number_of_policies
# 1    3251
# 2    2294
# 3    1168
# 7     433
# 9     416
# 4     409
# 5     407
# 8     384
# 6     372
# Name: count, dtype: int64

# %%
# I define a function to plot categorical
def plot_categorical(df):
    
    for col in df.columns:
        sns.catplot(data=df, x=col, kind="count")
        plt.xticks(rotation=45)
        plt.show()

# %%
# I substract the first column as it has unique values all along
categorical_filtered = categorical.drop(['customer'], axis=1)

# %%
plot_categorical(categorical_filtered)
# Out:
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# I plot 'effective_to_date' separately in a histogram plot to be able to see the distribution
sns.displot(categorical['effective_to_date'])
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\pablo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# I see different distributions among the different variables
# effective_to_date distribution doesn't have anything exceptional

# %%
# I will do a chi2_contingency test to check if there are any dependent(redundant) columns

# %%
categorical_cross = pd.crosstab(categorical['number_of_policies'], categorical['number_of_open_complaints'], margins = False)
categorical_cross
# Out:
# number_of_open_complaints     0    1    2   3   4   5
# number_of_policies
# 1                          2585  351  130  99  67  19
# 2                          1822  266   96  72  28  10
# 3                           924  134   51  27  24   8
# 4                           318   57   17  11   4   2
# 5                           327   36   12  18   5   9
# 6                           298   34   16  13   9   2
# 7                           342   47   18  17   5   4
# 8                           301   46   16  14   5   2
# 9                           335   40   18  21   2   0

# %%
import scipy.stats as st
st.chi2_contingency(categorical_cross)[1]
# H0: number_of_policies and number_of_open_complaints are not related
# p < 0.05 ===> We reject the H0 ===> we work under the assumption that they are related
# Out:
# 0.03730896172881451

# %%
# I can drop one of them, in order to build our model and I will drop 'number_of_policies'
# The reason why I will drop that column is that I will build a model to predict 'total_claim_amount'
# and my logic tells me that should be more related the 'number_of_open_complaints'. If a
# customer doesn't have any open complaints, his 'total_claim_amount' would be 0 and if he has
# a lot of open complaints his 'total_claim_amount' should tend to grow.

# %%
categorical = categorical.drop(['number_of_policies'], axis=1)
categorical.head()
# Out:
#   customer       state response  coverage education effective_to_date  \
# 0  BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1  QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2  AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3  WW63253  California       No     Basic  Bachelor        2011-01-20
# 4  HB64268  Washington       No     Basic  Bachelor        2011-02-03
#
#   employmentstatus gender location_code marital_status     policy_type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#   policy_level renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 0            3           Offer1         Agent   Two-Door Car      Medsize
# 1            3           Offer3         Agent  Four-Door Car      Medsize
# 2            3           Offer1         Agent   Two-Door Car      Medsize
# 3            2           Offer1   Call Center            SUV      Medsize
# 4            1           Offer1         Agent  Four-Door Car      Medsize
#
#   number_of_open_complaints
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0

# %%
# I will extract the day, month and year of 'effective_to_date' and convert them to integers.
categorical['year'] = categorical['effective_to_date'].dt.year
categorical['month'] = categorical['effective_to_date'].dt.month
categorical['day'] = categorical['effective_to_date'].dt.day

# %%
categorical.head()
# Out:
#   customer       state response  coverage education effective_to_date  \
# 0  BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1  QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2  AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3  WW63253  California       No     Basic  Bachelor        2011-01-20
# 4  HB64268  Washington       No     Basic  Bachelor        2011-02-03
#
#   employmentstatus gender location_code marital_status     policy_type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#   policy_level renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 0            3           Offer1         Agent   Two-Door Car      Medsize
# 1            3           Offer3         Agent  Four-Door Car      Medsize
# 2            3           Offer1         Agent   Two-Door Car      Medsize
# 3            2           Offer1   Call Center            SUV      Medsize
# 4            1           Offer1         Agent  Four-Door Car      Medsize
#
#   number_of_open_complaints  year  month  day
# 0                         0  2011      2   24
# 1                         0  2011      1   31
# 2                         0  2011      2   19
# 3                         0  2011      1   20
# 4                         0  2011      2    3

# %%
categorical.dtypes
# Out:
# customer                             object
# state                                object
# response                             object
# coverage                             object
# education                            object
# effective_to_date            datetime64[ns]
# employmentstatus                     object
# gender                               object
# location_code                        object
# marital_status                       object
# policy_type                          object
# policy_level                         object
# renew_offer_type                     object
# sales_channel                        object
# vehicle_class                        object
# vehicle_size                         object
# number_of_open_complaints            object
# year                                  int32
# month                                 int32
# day                                   int32
# dtype: object

# %%
# FINISH OF THE LAB

# %% [markdown]
# # Lab | Comparing regression models

# %% [markdown]
# Instructions:
#
# Concatenate Numerical and Categorical dataframes into one dataframe called data. Split into X=features y=target (total_claim_amount).
#
# 1. In this final lab, we will model our data. Import sklearn train_test_split and separate the data.
#
# 2. Separate X_train and X_test into numerical and categorical (X_train_cat , X_train_num , X_test_cat , X_test_num)
#
# 3. Use X_train_num to fit scalers. Transform BOTH X_train_num and X_test_num.
#
# 4. Encode the categorical variables X_train_cat and X_test_cat
#
# 5. Since the model will only accept numerical data, check and make sure that every column is numerical, if some are not, change it using encoding.
#
# 6. Try a simmple linear regression with all the data to see whether we are getting good results.
#
# 7. Great! Now define a function that takes a list of models and train (and tests) them so we can try a lot of them without repeating code.
#
# 8. Use the function to check LinearRegressor and KNeighborsRegressor.
#
# 9. You can check also the MLPRegressor for this task!
#
# 10. Check and discuss the results.

# %%
categorical.head()
# Out:
#   customer       state response  coverage education effective_to_date  \
# 0  BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1  QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2  AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3  WW63253  California       No     Basic  Bachelor        2011-01-20
# 4  HB64268  Washington       No     Basic  Bachelor        2011-02-03
#
#   employmentstatus gender location_code marital_status     policy_type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#   policy_level renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 0            3           Offer1         Agent   Two-Door Car      Medsize
# 1            3           Offer3         Agent  Four-Door Car      Medsize
# 2            3           Offer1         Agent   Two-Door Car      Medsize
# 3            2           Offer1   Call Center            SUV      Medsize
# 4            1           Offer1         Agent  Four-Door Car      Medsize
#
#   number_of_open_complaints  year  month  day
# 0                         0  2011      2   24
# 1                         0  2011      1   31
# 2                         0  2011      2   19
# 3                         0  2011      1   20
# 4                         0  2011      2    3

# %%
numerical.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# 2                          0                   2          566.472247
# 3                          0                   7          529.881344
# 4                          0                   1          138.130879

# %%
# I drop from numerical 'number_of_open_complaints' and 'number_of_policies' as I classified them
# as categorical before.
numerical = numerical.drop(['number_of_open_complaints', 'number_of_policies'], axis=1)

# %%
# I drop 'effective_to_date' from categorical as the information is already in the columns 'year', 'month' and 'day'
categorical = categorical.drop(['effective_to_date'], axis=1)

# %%
# concatenate categorical and numerical
data = pd.concat([categorical, numerical], axis=1)
data.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type  ... number_of_open_complaints  \
# 0      Suburban        Married  Corporate Auto  ...                         0
# 1      Suburban         Single   Personal Auto  ...                         0
# 2      Suburban        Married   Personal Auto  ...                         0
# 3      Suburban        Married  Corporate Auto  ...                         0
# 4         Rural         Single   Personal Auto  ...                         0
#
#    year month day customer_lifetime_value income  monthly_premium_auto  \
# 0  2011     2  24             2763.519279  56274                    69
# 1  2011     1  31             6979.535903      0                    94
# 2  2011     2  19            12887.431650  48767                   108
# 3  2011     1  20             7645.861827      0                   106
# 4  2011     2   3             2813.692575  43836                    73
#
#    months_since_last_claim  months_since_policy_inception  total_claim_amount
# 0                       32                              5          384.811147
# 1                       13                             42         1131.464935
# 2                       18                             38          566.472247
# 3                       18                             65          529.881344
# 4                       12                             44          138.130879
#
# [5 rows x 25 columns]

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type policy_level renew_offer_type  \
# 0      Suburban        Married  Corporate Auto            3           Offer1
# 1      Suburban         Single   Personal Auto            3           Offer3
# 2      Suburban        Married   Personal Auto            3           Offer1
# 3      Suburban        Married  Corporate Auto            2           Offer1
# 4         Rural         Single   Personal Auto            1           Offer1
#
#   sales_channel  vehicle_class vehicle_size number_of_open_complaints  year  \
# 0         Agent   Two-Door Car      Medsize                         0  2011
# 1         Agent  Four-Door Car      Medsize                         0  2011
# 2         Agent   Two-Door Car      Medsize                         0  2011
# 3   Call Center            SUV      Medsize                         0  2011
# 4         Agent  Four-Door Car      Medsize                         0  2011
#
#    month  day  customer_lifetime_value  income  monthly_premium_auto  \
# 0      2   24              2763.519279   56274                    69
# 1      1   31              6979.535903       0                    94
# 2      2   19             12887.431650   48767                   108
# 3      1   20              7645.861827       0                   106
# 4      2    3              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  total_claim_amount
# 0                       32                              5          384.811147
# 1                       13                             42         1131.464935
# 2                       18                             38          566.472247
# 3                       18                             65          529.881344
# 4                       12                             44          138.130879

# %%
# First I have to drop 'customer' column as are not useful to fit the model
data = data.drop(['customer'], axis=1)

# %%
# X-y split
X = data.drop(['total_claim_amount'],axis=1)
y = data['total_claim_amount']

# %%
# train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7307, 23)
# (1827, 23)
# (7307,)
# (1827,)

# %%
# split X train and test into categorical and numerical
X_train_cat = X_train.select_dtypes(exclude='number')
X_test_cat = X_test.select_dtypes(exclude='number')

X_train_num = X_train.select_dtypes('number')
X_test_num = X_test.select_dtypes('number')

# %%
print(X_train_num.dtypes)
print(X_test_num.dtypes)
print(X_train_cat.dtypes)
print(X_test_cat.dtypes)
# Out:
# year                               int32
# month                              int32
# day                                int32
# customer_lifetime_value          float64
# income                             int64
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# dtype: object
# year                               int32
# month                              int32
# day                                int32
# customer_lifetime_value          float64
# income                             int64
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# dtype: object
# state                        object
# response                     object
# coverage                     object
# education                    object
# employmentstatus             object
# gender                       object
# location_code                object
# marital_status               object
# policy_type                  object
# policy_level                 object
# renew_offer_type             object
# sales_channel                object
# vehicle_class                object
# vehicle_size                 object
# number_of_open_complaints    object
# dtype: object
# state                        object
# response                     object
# coverage                     object
# education                    object
# employmentstatus             object
# gender                       object
# location_code                object
# marital_status               object
# policy_type                  object
# policy_level                 object
# renew_offer_type             object
# sales_channel                object
# vehicle_class                object
# vehicle_size                 object
# number_of_open_complaints    object
# dtype: object

# %%
# Scale X_train_num and X_test_num
from sklearn.preprocessing import StandardScaler

# scaling standard scaler: make data distributed with mean=0 and std=1
transformer = StandardScaler().fit(X_train_num)
numericals_train_standardized = transformer.transform(X_train_num)
numericals_test_standardized = transformer.transform(X_test_num)

# %%
# Encode X_train_cat and X_test_cat
# There are some features that I will onehot encode and others that I will ordinal encode
# I will perform ordinal encode in 'coverage', 'employmentstatus', 'location code', 'vehicle size'
# and 'education' as they are ordinal features

# %%
X_train_cat.head()
# Out:
#            state response  coverage education employmentstatus gender  \
# 996       Oregon      Yes     Basic    Master         Employed      F
# 8913  California       No  Extended   College         Employed      M
# 4607  California       No     Basic  Bachelor       Unemployed      M
# 5429  California       No     Basic  Bachelor         Employed      F
# 7428  California      Yes     Basic  Bachelor         Disabled      M
#
#      location_code marital_status    policy_type policy_level  \
# 996       Suburban         Single  Personal Auto            2
# 8913      Suburban       Divorced  Personal Auto            2
# 4607      Suburban         Single  Personal Auto            2
# 5429      Suburban       Divorced  Personal Auto            3
# 7428      Suburban        Married  Personal Auto            2
#
#      renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 996            Offer2        Branch            SUV        Large
# 8913           Offer4           Web  Four-Door Car        Large
# 4607           Offer4        Branch  Four-Door Car      Medsize
# 5429           Offer4           Web   Two-Door Car        Large
# 7428           Offer1        Branch     Sports Car        Large
#
#      number_of_open_complaints
# 996                          1
# 8913                         0
# 4607                         1
# 5429                         0
# 7428                         0

# %%
for col in X_train_cat:
    print(X_train_cat[col].value_counts())
# Out:
# state
# California    2519
# Oregon        2050
# Arizona       1368
# Nevada         718
# Washington     652
# Name: count, dtype: int64
# response
# No     6262
# Yes    1045
# Name: count, dtype: int64
# coverage
# Basic       4454
# Extended    2185
# Premium      668
# Name: count, dtype: int64
# education
# Bachelor                2184
# College                 2140
# High School or Below    2097
# Master                   614
# Doctor                   272
# Name: count, dtype: int64
# employmentstatus
# Employed         4566
# Unemployed       1856
# Disabled          337
# Medical Leave     328
# Retired           220
# Name: count, dtype: int64
# gender
# F    3681
# M    3626
# Name: count, dtype: int64
# location_code
# Suburban    4624
# Rural       1421
# Urban       1262
# Name: count, dtype: int64
# marital_status
# Married     4245
# Single      1974
# Divorced    1088
# Name: count, dtype: int64
# policy_type
# Personal Auto     5417
# Corporate Auto    1574
# Special Auto       316
# Name: count, dtype: int64
# policy_level
# 3    3648
# 2    2312
# 1    1347
# Name: count, dtype: int64
# renew_offer_type
# Offer1    2955
# Offer2    2333
# Offer3    1192
# Offer4     827
# Name: count, dtype: int64
# sales_channel
# Agent          2821
# Branch         2040
# Call Center    1389
# Web            1057
# Name: count, dtype: int64
# vehicle_class
# Four-Door Car    3752
# Two-Door Car     1501
# SUV              1393
# Sports Car        376
# Luxury SUV        143
# Luxury Car        142
# Name: count, dtype: int64
# vehicle_size
# Medsize    5157
# Small      1406
# Large       744
# Name: count, dtype: int64
# number_of_open_complaints
# 0    5792
# 1     799
# 2     308
# 3     241
# 4     124
# 5      43
# Name: count, dtype: int64

# %%
# So I will split them
X_train_cat_onehot = X_train_cat[['']]
X_train_cat_ordinal = 

X_test_cat_onehot
X_test_cat_ordinal
